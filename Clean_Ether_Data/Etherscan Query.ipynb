# %%
import pandas as pd
import requests
import time

df = pd.read_csv(r"/Users/ramy/Documents/GitHub/LogicalDistillationOfGNNs/EtherScamDB/EtherScamDB-master/_data/scams.csv")
df["scam_address"] = df["scam_address"].str.replace(r"[\[\]']", "", regex=True).str.split(", ")

df = df.explode("scam_address").reset_index(drop=True)
addresses = df["scam_address"].tolist()

ETHERSCAN_API_KEY = "3GS49BKCP8XK873Y1B27MR1WSBUIVSZSRD"

def get_transactions(address):
    url = f"https://api.etherscan.io/api?module=account&action=txlist&address={address}&startblock=0&endblock=99999999&sort=desc&apikey={ETHERSCAN_API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if data["status"] == "1":
        return data["result"]
    else:
        print(f"Error fetching {address}: {data['message']}")
        return []

all_transactions = []
for address in addresses:
    transactions = get_transactions(address.strip())
    for tx in transactions:
        tx["scam_address"] = address
        all_transactions.append(tx)
    time.sleep(0.5)

tx_df = pd.DataFrame(all_transactions)
tx_df.to_csv("scam_transactions.csv", index=False)

print("Transaction data saved successfully!")

# %%
scams_df = pd.read_csv(r"/Users/ramy/Documents/GitHub/LogicalDistillationOfGNNs/EtherScamDB/EtherScamDB-master/_data/scams.csv")
scams_df["scam_address"] = scams_df["scam_address"].str.replace(r"[\[\]']", "", regex=True).str.split(", ")
exploded_scams_df = scams_df.explode("scam_address")

transactions_df = pd.read_csv("/Users/ramy/Documents/GitHub/LogicalDistillationOfGNNs/scam_transactions.csv")
merged_df = pd.merge(exploded_scams_df, transactions_df, on="scam_address", how="right")

# %%
import pandas as pd
import requests
import time

# Read legitimate addresses
df = pd.read_csv(r'/Users/ramy/Documents/GitHub/LogicalDistillationOfGNNs/Clean_Ether_Data/Legit_Etherscan_Address.csv')
df = df[df["Trans_Type"] != "ICO_Wallet"]

# Extract addresses from the dataframe - assuming there's an address column
addresses = df["Address"].tolist()  # Adjust column name if needed

ETHERSCAN_API_KEY = "3GS49BKCP8XK873Y1B27MR1WSBUIVSZSRD"

def get_transactions(address):
    url = f"https://api.etherscan.io/api?module=account&action=txlist&address={address}&startblock=0&endblock=99999999&sort=desc&apikey={ETHERSCAN_API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if data["status"] == "1":
        return data["result"]
    else:
        print(f"Error fetching {address}: {data['message']}")
        return []
    
all_transactions = []
for i, address in enumerate(addresses):
    print(f"Processing address {i+1}/{len(addresses)}: {address}")
    transactions = get_transactions(address.strip())
    for tx in transactions:
        tx["queried_address"] = address 
        all_transactions.append(tx)
    time.sleep(0.5) 

tx_df = pd.DataFrame(all_transactions)
tx_df['category'] = 0 
tx_df.to_csv(r"/Users/ramy/Documents/GitHub/LogicalDistillationOfGNNs/Clean_Ether_Data/legit_trans_query.csv", index=False)
print(f"Saved {len(all_transactions)} transactions from {len(addresses)} addresses")
# Out:
# Processing address 1/145: 0x777f415324d56e1d54fa832902d8797db7a4c57c
# Processing address 2/145: 0xe84a69675d316a639203b527919504b33e8d6f20
# Processing address 110/145: 0x537b6bd3caeb0d41540ac1fd406b9acda5670aad
# Processing address 111/145: 0x55bb709b7a5c51a0c25ea6424931d5c8545c59db
# Processing address 112/145: 0x5dcb78343780e1b1e578ae0590dc1e868792a435
# Processing address 113/145: 0x646db8ffc21e7ddc2b6327448dd9fa560df41087
# Processing address 114/145: 0x6ebaf477f83e055589c1188bcc6ddccd8c9b131a
# Processing address 115/145: 0x8f03f1a3f10c05e7cccf75c1fd10168e06659be7
# Processing address 116/145: 0xab3b229eb4bcff881275e7ea2f0fd24eeac8c83a
# Processing address 117/145: 0xaee98861388af1d6323b95f78adf3dda102a276c
# Processing address 118/145: 0xb7e390864a90b7b923c9f9310c6f98aafe43f707
# Processing address 119/145: 0xbc78d75867b04f996ef1050d8090b8ccb91f09af
# Processing address 120/145: 0xc8f595e2084db484f8a80109101d58625223b7c9
# Processing address 121/145: 0xc93452a74e596e81e4f73ca1acff532089ad4c62
# Processing address 122/145: 0x09ab1303d3ccaf5f018cd511146b07a240c70294
# Processing address 123/145: 0xbbbbbbbb49459e69878219f906e73aa325ff2f0c
# Processing address 124/145: 0x06b8c5883ec71bc3f4b332081519f23834c8706e
# Processing address 125/145: 0x3ecef08d0e2dad803847e052249bb4f8bff2d5bb
# Processing address 126/145: 0x2a98776c7e13ed1c240858bd241dcf95fc1928b4
# Processing address 127/145: 0x52bc44d5378309ee2abf1539bf71de1b7d7be3b5
# Processing address 128/145: 0x2f979c933aef4fcddd27c0fa5c54d8a780555b0a
# Processing address 129/145: 0x776bb566dc299c9e722773d2a04b401e831a6dc8
# Processing address 130/145: 0x6b7d50bb8fab584e54251a10e1c6cfa51dd7b618
# Processing address 131/145: 0x47c439c8784b44366735fc2cfe08228cb91d5b8e
# Processing address 132/145: 0xa7b0536fb02c593b0dfd82bd65aacbdd19ae4777
# Processing address 133/145: 0x2daa35962a6d43eb54c48367b33d0b379c930e5e
# Processing address 134/145: 0x2a20380dca5bc24d052acfbf79ba23e988ad0050
# Processing address 135/145: 0xcd458d7f11023556cc9058f729831a038cb8df9c
# Processing address 136/145: 0x8b4de256180cfec54c436a470af50f9ee2813dbb
# Processing address 137/145: 0x5a0b54d5dc17e0aadc383d2db43b0a0d3e029c4c
# Processing address 138/145: 0x1dcb8d1f0fcc8cbc8c2d76528e877f915e299fbe
# Processing address 139/145: 0x63a9975ba31b0b9626b34300f7f627147df1f526
# Processing address 140/145: 0xa3c084ae80a3f03963017669bc696e961d3ae5d5
# Processing address 141/145: 0x44fd3ab8381cc3d14afa7c4af7fd13cdc65026e1
# Processing address 142/145: 0x9435d50503aee35c8757ae4933f7a0ab56597805
# Processing address 143/145: 0x7c6694032b4db11ac485e1cff0f7509d58b41569
# Processing address 144/145: 0x6a851246689eb8fc77a9bf68df5860f13f679fa0
# Processing address 145/145: 0x04668ec2f57cc15c381b461b9fedab5d451c8f7f
# Saved 794302 transactions from 145 addresses
